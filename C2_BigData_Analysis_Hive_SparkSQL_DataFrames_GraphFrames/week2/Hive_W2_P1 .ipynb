# %% [markdown]
# %%writefile creation_db.hql
#
# DROP DATABASE IF EXISTS demodb CASCADE;

# %% [markdown]
# %%writefile -a creation_db.hql
# CREATE DATABASE demodb LOCATION '/user/jovyan/somemetastore';

# %% [markdown]
# ! hive -f creation_db.hql

# %%
# %%writefile external_table.hql
#
# ADD JAR /opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar;
#
# USE demodb;
# DROP TABLE IF EXISTS posts_sample_external;
# DROP TABLE IF EXISTS posts_sample;
# CREATE EXTERNAL TABLE posts_sample_external (
# id int,
# posttypeid int,
# creationdate string,
# tags string,
# owneruserid int,
# parentid int,
# score int,
# favoritecount int
# )
# ROW FORMAT
# SERDE 'org.apache.hadoop.hive.serde2.RegexSerDe'
# WITH SERDEPROPERTIES (
# "input.regex" = '\<row (?=.*\\bId=\"(\\d+))(?=.*\\bPostTypeId=\"(\\d+))(?=.*\\bCreationDate=\"([0-9-T:.]+)\")(?=.*\\bTags=\"(\\S+)\")?(?=.*\bOwnerUserId=\"(\\d+))?(?=.*\\bParentId=\"(\\d+))?(?=.*\\bScore=\"(\\d\+))(?=.*\\bFavoriteCount =\"(\\d+))?.*$'
# )
# LOCATION '/data/stackexchange1000/posts/';
#
# CREATE TABLE posts_sample (
# id int,
# posttypeid int,
# creationdate string,
# tags string,
# owneruserid int,
# parentid int,
# score int,
# favoritecount int
# )
# PARTITIONED BY (year STRING,month STRING)
# ROW FORMAT DELIMITED
# FIELDS TERMINATED BY ','
# STORED AS TEXTFILE;
# Out:
# Overwriting external_table.hql

# %%
# %%writefile -a external_table.hql
# SET hive.exec.dynamic.partition = true;
# set hive.exec.dynamic.partition.mode=nonstrict;
# set hive.exec.max.dynamic.partitions=2000;
# set hive.exec.max.dynamic.partitions.pernode=1000;
# INSERT OVERWRITE TABLE posts_sample partition(year,month)
# Select
# id ,
# posttypeid ,
# creationdate ,
# tags ,
# owneruserid ,
# parentid ,
# score ,
# favoritecount,
# substr(creationdate,1,4) as year,
# substr(creationdate,1,7) as month
# from posts_sample_external ;
# with
# B as
# (
#     select year,month,cnt,row_number() over(order by month asc) as rn from A
# ),
# A as
# (select year,month,count(*) as cnt from posts_sample group by year,month )
# select year,month,cnt from B where rn=3;
# Out:
# Appending to external_table.hql

# %%
! hive -f external_table.hql
# Out:
# Logging initialized using configuration in jar:file:/usr/local/apache-hive-1.1.0-bin/lib/hive-common-1.1.0.jar!/hive-log4j.properties
# Added [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar] to class path
# Added resources: [/opt/cloudera/parcels/CDH/lib/hive/lib/hive-contrib.jar]
# OK
# Time taken: 1.088 seconds
# OK
# Time taken: 1.588 seconds
# OK
# Time taken: 3.149 seconds
# OK
# Time taken: 0.698 seconds
# OK
# Time taken: 0.291 seconds
# Query ID = jovyan_20180228054242_c63011ea-fd31-4966-87b5-9bbcb58fed47
# Total jobs = 3
# Launching Job 1 out of 3
# Number of reduce tasks is set to 0 since there's no reduce operator
# Starting Job = job_1519792833153_0011, Tracking URL = http://f860572437fc:8088/proxy/application_1519792833153_0011/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1519792833153_0011
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 0
# 2018-02-28 05:42:49,523 Stage-1 map = 0%,  reduce = 0%
# 2018-02-28 05:43:09,031 Stage-1 map = 24%,  reduce = 0%, Cumulative CPU 17.7 sec
# 2018-02-28 05:43:14,385 Stage-1 map = 40%,  reduce = 0%, Cumulative CPU 24.19 sec
# 2018-02-28 05:43:20,774 Stage-1 map = 54%,  reduce = 0%, Cumulative CPU 30.03 sec
# 2018-02-28 05:43:27,151 Stage-1 map = 71%,  reduce = 0%, Cumulative CPU 36.14 sec
# 2018-02-28 05:43:32,472 Stage-1 map = 87%,  reduce = 0%, Cumulative CPU 42.69 sec
# 2018-02-28 05:43:38,880 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 48.33 sec
# MapReduce Total cumulative CPU time: 48 seconds 330 msec
# Ended Job = job_1519792833153_0011
# Stage-4 is selected by condition resolver.
# Stage-3 is filtered out by condition resolver.
# Stage-5 is filtered out by condition resolver.
# Moving data to: hdfs://localhost:9000/user/jovyan/somemetastore/posts_sample/.hive-staging_hive_2018-02-28_05-42-33_268_5760269109056660367-1/-ext-10000
# Loading data to table demodb.posts_sample partition (year=null, month=null)
# 	 Time taken for load dynamic partitions : 11024
# 	Loading partition {year=2013, month=2013-10}
# 	Loading partition {year=2014, month=2014-06}
# 	Loading partition {year=2012, month=2012-11}
# 	Loading partition {year=2013, month=2013-07}
# 	Loading partition {year=2013, month=2013-01}
# 	Loading partition {year=2012, month=2012-02}
# 	Loading partition {year=2011, month=2011-12}
# 	Loading partition {year=2010, month=2010-09}
# 	Loading partition {year=2011, month=2011-08}
# 	Loading partition {year=2010, month=2010-04}
# 	Loading partition {year=2011, month=2011-03}
# 	Loading partition {year=2012, month=2012-07}
# 	Loading partition {year=2014, month=2014-10}
# 	Loading partition {year=2011, month=2011-02}
# 	Loading partition {year=2012, month=2012-01}
# 	Loading partition {year=2010, month=2010-03}
# 	Loading partition {year=2013, month=2013-11}
# 	Loading partition {year=2010, month=2010-08}
# 	Loading partition {year=2012, month=2012-12}
# 	Loading partition {year=2010, month=2010-11}
# 	Loading partition {year=2010, month=2010-05}
# 	Loading partition {year=2009, month=2009-06}
# 	Loading partition {year=2009, month=2009-12}
# 	Loading partition {year=2016, month=2016-06}
# 	Loading partition {year=2016, month=2016-12}
# 	Loading partition {year=2010, month=2010-02}
# 	Loading partition {year=2013, month=2013-08}
# 	Loading partition {year=2015, month=2015-04}
# 	Loading partition {year=2008, month=2008-09}
# 	Loading partition {year=2015, month=2015-09}
# 	Loading partition {year=2008, month=2008-10}
# 	Loading partition {year=2013, month=2013-12}
# 	Loading partition {year=2015, month=2015-10}
# 	Loading partition {year=2015, month=2015-01}
# 	Loading partition {year=2013, month=2013-06}
# 	Loading partition {year=2008, month=2008-12}
# 	Loading partition {year=2015, month=2015-12}
# 	Loading partition {year=2013, month=2013-03}
# 	Loading partition {year=2015, month=2015-06}
# 	Loading partition {year=2011, month=2011-11}
# 	Loading partition {year=2011, month=2011-05}
# 	Loading partition {year=2009, month=2009-10}
# 	Loading partition {year=2016, month=2016-10}
# 	Loading partition {year=2012, month=2012-08}
# 	Loading partition {year=2014, month=2014-01}
# 	Loading partition {year=2009, month=2009-09}
# 	Loading partition {year=2016, month=2016-09}
# 	Loading partition {year=2012, month=2012-03}
# 	Loading partition {year=2009, month=2009-04}
# 	Loading partition {year=2016, month=2016-04}
# 	Loading partition {year=2014, month=2014-09}
# 	Loading partition {year=2014, month=2014-03}
# 	Loading partition {year=2014, month=2014-12}
# 	Loading partition {year=2008, month=2008-08}
# 	Loading partition {year=2015, month=2015-08}
# 	Loading partition {year=2015, month=2015-02}
# 	Loading partition {year=2013, month=2013-04}
# 	Loading partition {year=2012, month=2012-05}
# 	Loading partition {year=2011, month=2011-06}
# 	Loading partition {year=2010, month=2010-10}
# 	Loading partition {year=2010, month=2010-07}
# 	Loading partition {year=2009, month=2009-02}
# 	Loading partition {year=2016, month=2016-02}
# 	Loading partition {year=2013, month=2013-09}
# 	Loading partition {year=2014, month=2014-08}
# 	Loading partition {year=2015, month=2015-03}
# 	Loading partition {year=2014, month=2014-04}
# 	Loading partition {year=2009, month=2009-07}
# 	Loading partition {year=2016, month=2016-07}
# 	Loading partition {year=2013, month=2013-05}
# 	Loading partition {year=2009, month=2009-01}
# 	Loading partition {year=2012, month=2012-06}
# 	Loading partition {year=2016, month=2016-01}
# 	Loading partition {year=2011, month=2011-07}
# 	Loading partition {year=2011, month=2011-01}
# 	Loading partition {year=2011, month=2011-04}
# 	Loading partition {year=2012, month=2012-09}
# 	Loading partition {year=2011, month=2011-10}
# 	Loading partition {year=2009, month=2009-03}
# 	Loading partition {year=2015, month=2015-07}
# 	Loading partition {year=2016, month=2016-03}
# 	Loading partition {year=2014, month=2014-02}
# 	Loading partition {year=2014, month=2014-05}
# 	Loading partition {year=2014, month=2014-11}
# 	Loading partition {year=2009, month=2009-05}
# 	Loading partition {year=2009, month=2009-08}
# 	Loading partition {year=2016, month=2016-08}
# 	Loading partition {year=2016, month=2016-05}
# 	Loading partition {year=2012, month=2012-04}
# 	Loading partition {year=2016, month=2016-11}
# 	Loading partition {year=2009, month=2009-11}
# 	Loading partition {year=2010, month=2010-01}
# 	Loading partition {year=2011, month=2011-09}
# 	Loading partition {year=2014, month=2014-07}
# 	Loading partition {year=2012, month=2012-10}
# 	Loading partition {year=2010, month=2010-06}
# 	Loading partition {year=2010, month=2010-12}
# 	Loading partition {year=2008, month=2008-11}
# 	Loading partition {year=2015, month=2015-11}
# 	Loading partition {year=2013, month=2013-02}
# 	Loading partition {year=2015, month=2015-05}
# 	Loading partition {year=__HIVE_DEFAULT_PARTITION__, month=__HIVE_DEFAULT_PARTITION__}
# 	 Time taken for adding to write entity : 35
# Partition demodb.posts_sample{year=2008, month=2008-08} stats: [numFiles=1, numRows=23, totalSize=1184, rawDataSize=1161]
# Partition demodb.posts_sample{year=2008, month=2008-09} stats: [numFiles=1, numRows=86, totalSize=4665, rawDataSize=4579]
# Partition demodb.posts_sample{year=2008, month=2008-10} stats: [numFiles=1, numRows=71, totalSize=3997, rawDataSize=3926]
# Partition demodb.posts_sample{year=2008, month=2008-11} stats: [numFiles=1, numRows=54, totalSize=3313, rawDataSize=3259]
# Partition demodb.posts_sample{year=2008, month=2008-12} stats: [numFiles=1, numRows=48, totalSize=2924, rawDataSize=2876]
# Partition demodb.posts_sample{year=2009, month=2009-01} stats: [numFiles=1, numRows=82, totalSize=4703, rawDataSize=4621]
# Partition demodb.posts_sample{year=2009, month=2009-02} stats: [numFiles=1, numRows=83, totalSize=4750, rawDataSize=4667]
# Partition demodb.posts_sample{year=2009, month=2009-03} stats: [numFiles=1, numRows=83, totalSize=5094, rawDataSize=5011]
# Partition demodb.posts_sample{year=2009, month=2009-04} stats: [numFiles=1, numRows=93, totalSize=5946, rawDataSize=5853]
# Partition demodb.posts_sample{year=2009, month=2009-05} stats: [numFiles=1, numRows=109, totalSize=6741, rawDataSize=6632]
# Partition demodb.posts_sample{year=2009, month=2009-06} stats: [numFiles=1, numRows=119, totalSize=7380, rawDataSize=7261]
# Partition demodb.posts_sample{year=2009, month=2009-07} stats: [numFiles=1, numRows=131, totalSize=8408, rawDataSize=8277]
# Partition demodb.posts_sample{year=2009, month=2009-08} stats: [numFiles=1, numRows=129, totalSize=7885, rawDataSize=7756]
# Partition demodb.posts_sample{year=2009, month=2009-09} stats: [numFiles=1, numRows=126, totalSize=7991, rawDataSize=7865]
# Partition demodb.posts_sample{year=2009, month=2009-10} stats: [numFiles=1, numRows=132, totalSize=8220, rawDataSize=8088]
# Partition demodb.posts_sample{year=2009, month=2009-11} stats: [numFiles=1, numRows=145, totalSize=9397, rawDataSize=9252]
# Partition demodb.posts_sample{year=2009, month=2009-12} stats: [numFiles=1, numRows=144, totalSize=9251, rawDataSize=9107]
# Partition demodb.posts_sample{year=2010, month=2010-01} stats: [numFiles=1, numRows=174, totalSize=11059, rawDataSize=10885]
# Partition demodb.posts_sample{year=2010, month=2010-02} stats: [numFiles=1, numRows=158, totalSize=10341, rawDataSize=10183]
# Partition demodb.posts_sample{year=2010, month=2010-03} stats: [numFiles=1, numRows=187, totalSize=12366, rawDataSize=12179]
# Partition demodb.posts_sample{year=2010, month=2010-04} stats: [numFiles=1, numRows=174, totalSize=11805, rawDataSize=11631]
# Partition demodb.posts_sample{year=2010, month=2010-05} stats: [numFiles=1, numRows=166, totalSize=10607, rawDataSize=10441]
# Partition demodb.posts_sample{year=2010, month=2010-06} stats: [numFiles=1, numRows=200, totalSize=13093, rawDataSize=12893]
# Partition demodb.posts_sample{year=2010, month=2010-07} stats: [numFiles=1, numRows=205, totalSize=14196, rawDataSize=13991]
# Partition demodb.posts_sample{year=2010, month=2010-08} stats: [numFiles=1, numRows=211, totalSize=13948, rawDataSize=13737]
# Partition demodb.posts_sample{year=2010, month=2010-09} stats: [numFiles=1, numRows=202, totalSize=13739, rawDataSize=13537]
# Partition demodb.posts_sample{year=2010, month=2010-10} stats: [numFiles=1, numRows=217, totalSize=13954, rawDataSize=13737]
# Partition demodb.posts_sample{year=2010, month=2010-11} stats: [numFiles=1, numRows=230, totalSize=15333, rawDataSize=15103]
# Partition demodb.posts_sample{year=2010, month=2010-12} stats: [numFiles=1, numRows=236, totalSize=15476, rawDataSize=15240]
# Partition demodb.posts_sample{year=2011, month=2011-01} stats: [numFiles=1, numRows=273, totalSize=18392, rawDataSize=18119]
# Partition demodb.posts_sample{year=2011, month=2011-02} stats: [numFiles=1, numRows=269, totalSize=18161, rawDataSize=17892]
# Partition demodb.posts_sample{year=2011, month=2011-03} stats: [numFiles=1, numRows=346, totalSize=22793, rawDataSize=22447]
# Partition demodb.posts_sample{year=2011, month=2011-04} stats: [numFiles=1, numRows=318, totalSize=20739, rawDataSize=20421]
# Partition demodb.posts_sample{year=2011, month=2011-05} stats: [numFiles=1, numRows=324, totalSize=21827, rawDataSize=21503]
# Partition demodb.posts_sample{year=2011, month=2011-06} stats: [numFiles=1, numRows=339, totalSize=22503, rawDataSize=22164]
# Partition demodb.posts_sample{year=2011, month=2011-07} stats: [numFiles=1, numRows=329, totalSize=21881, rawDataSize=21552]
# Partition demodb.posts_sample{year=2011, month=2011-08} stats: [numFiles=1, numRows=353, totalSize=23490, rawDataSize=23137]
# Partition demodb.posts_sample{year=2011, month=2011-09} stats: [numFiles=1, numRows=342, totalSize=23201, rawDataSize=22859]
# Partition demodb.posts_sample{year=2011, month=2011-10} stats: [numFiles=1, numRows=322, totalSize=21695, rawDataSize=21373]
# Partition demodb.posts_sample{year=2011, month=2011-11} stats: [numFiles=1, numRows=355, totalSize=24120, rawDataSize=23765]
# Partition demodb.posts_sample{year=2011, month=2011-12} stats: [numFiles=1, numRows=341, totalSize=22384, rawDataSize=22043]
# Partition demodb.posts_sample{year=2012, month=2012-01} stats: [numFiles=1, numRows=370, totalSize=24081, rawDataSize=23711]
# Partition demodb.posts_sample{year=2012, month=2012-02} stats: [numFiles=1, numRows=406, totalSize=28056, rawDataSize=27650]
# Partition demodb.posts_sample{year=2012, month=2012-03} stats: [numFiles=1, numRows=424, totalSize=28772, rawDataSize=28348]
# Partition demodb.posts_sample{year=2012, month=2012-04} stats: [numFiles=1, numRows=407, totalSize=28397, rawDataSize=27990]
# Partition demodb.posts_sample{year=2012, month=2012-05} stats: [numFiles=1, numRows=416, totalSize=28943, rawDataSize=28527]
# Partition demodb.posts_sample{year=2012, month=2012-06} stats: [numFiles=1, numRows=408, totalSize=27678, rawDataSize=27270]
# Partition demodb.posts_sample{year=2012, month=2012-07} stats: [numFiles=1, numRows=438, totalSize=31159, rawDataSize=30721]
# Partition demodb.posts_sample{year=2012, month=2012-08} stats: [numFiles=1, numRows=438, totalSize=29676, rawDataSize=29238]
# Partition demodb.posts_sample{year=2012, month=2012-09} stats: [numFiles=1, numRows=391, totalSize=26655, rawDataSize=26264]
# Partition demodb.posts_sample{year=2012, month=2012-10} stats: [numFiles=1, numRows=453, totalSize=31656, rawDataSize=31203]
# Partition demodb.posts_sample{year=2012, month=2012-11} stats: [numFiles=1, numRows=428, totalSize=29413, rawDataSize=28985]
# Partition demodb.posts_sample{year=2012, month=2012-12} stats: [numFiles=1, numRows=404, totalSize=26630, rawDataSize=26226]
# Partition demodb.posts_sample{year=2013, month=2013-01} stats: [numFiles=1, numRows=471, totalSize=31397, rawDataSize=30926]
# Partition demodb.posts_sample{year=2013, month=2013-02} stats: [numFiles=1, numRows=465, totalSize=32394, rawDataSize=31929]
# Partition demodb.posts_sample{year=2013, month=2013-03} stats: [numFiles=1, numRows=509, totalSize=34823, rawDataSize=34314]
# Partition demodb.posts_sample{year=2013, month=2013-04} stats: [numFiles=1, numRows=513, totalSize=36162, rawDataSize=35649]
# Partition demodb.posts_sample{year=2013, month=2013-05} stats: [numFiles=1, numRows=509, totalSize=34949, rawDataSize=34440]
# Partition demodb.posts_sample{year=2013, month=2013-06} stats: [numFiles=1, numRows=460, totalSize=32273, rawDataSize=31813]
# Partition demodb.posts_sample{year=2013, month=2013-07} stats: [numFiles=1, numRows=530, totalSize=37231, rawDataSize=36701]
# Partition demodb.posts_sample{year=2013, month=2013-08} stats: [numFiles=1, numRows=518, totalSize=36211, rawDataSize=35693]
# Partition demodb.posts_sample{year=2013, month=2013-09} stats: [numFiles=1, numRows=490, totalSize=34687, rawDataSize=34197]
# Partition demodb.posts_sample{year=2013, month=2013-10} stats: [numFiles=1, numRows=554, totalSize=37490, rawDataSize=36936]
# Partition demodb.posts_sample{year=2013, month=2013-11} stats: [numFiles=1, numRows=530, totalSize=36690, rawDataSize=36160]
# Partition demodb.posts_sample{year=2013, month=2013-12} stats: [numFiles=1, numRows=497, totalSize=34757, rawDataSize=34260]
# Partition demodb.posts_sample{year=2014, month=2014-01} stats: [numFiles=1, numRows=576, totalSize=41058, rawDataSize=40482]
# Partition demodb.posts_sample{year=2014, month=2014-02} stats: [numFiles=1, numRows=569, totalSize=40060, rawDataSize=39491]
# Partition demodb.posts_sample{year=2014, month=2014-03} stats: [numFiles=1, numRows=601, totalSize=42201, rawDataSize=41600]
# Partition demodb.posts_sample{year=2014, month=2014-04} stats: [numFiles=1, numRows=575, totalSize=40531, rawDataSize=39956]
# Partition demodb.posts_sample{year=2014, month=2014-05} stats: [numFiles=1, numRows=518, totalSize=35559, rawDataSize=35041]
# Partition demodb.posts_sample{year=2014, month=2014-06} stats: [numFiles=1, numRows=468, totalSize=33947, rawDataSize=33479]
# Partition demodb.posts_sample{year=2014, month=2014-07} stats: [numFiles=1, numRows=507, totalSize=35605, rawDataSize=35098]
# Partition demodb.posts_sample{year=2014, month=2014-08} stats: [numFiles=1, numRows=481, totalSize=33501, rawDataSize=33020]
# Partition demodb.posts_sample{year=2014, month=2014-09} stats: [numFiles=1, numRows=472, totalSize=33246, rawDataSize=32774]
# Partition demodb.posts_sample{year=2014, month=2014-10} stats: [numFiles=1, numRows=504, totalSize=35979, rawDataSize=35475]
# Partition demodb.posts_sample{year=2014, month=2014-11} stats: [numFiles=1, numRows=475, totalSize=33909, rawDataSize=33434]
# Partition demodb.posts_sample{year=2014, month=2014-12} stats: [numFiles=1, numRows=463, totalSize=33835, rawDataSize=33372]
# Partition demodb.posts_sample{year=2015, month=2015-01} stats: [numFiles=1, numRows=474, totalSize=32941, rawDataSize=32467]
# Partition demodb.posts_sample{year=2015, month=2015-02} stats: [numFiles=1, numRows=484, totalSize=34240, rawDataSize=33756]
# Partition demodb.posts_sample{year=2015, month=2015-03} stats: [numFiles=1, numRows=541, totalSize=38008, rawDataSize=37467]
# Partition demodb.posts_sample{year=2015, month=2015-04} stats: [numFiles=1, numRows=550, totalSize=37749, rawDataSize=37199]
# Partition demodb.posts_sample{year=2015, month=2015-05} stats: [numFiles=1, numRows=546, totalSize=38555, rawDataSize=38009]
# Partition demodb.posts_sample{year=2015, month=2015-06} stats: [numFiles=1, numRows=539, totalSize=38662, rawDataSize=38123]
# Partition demodb.posts_sample{year=2015, month=2015-07} stats: [numFiles=1, numRows=561, totalSize=40695, rawDataSize=40134]
# Partition demodb.posts_sample{year=2015, month=2015-08} stats: [numFiles=1, numRows=535, totalSize=38618, rawDataSize=38083]
# Partition demodb.posts_sample{year=2015, month=2015-09} stats: [numFiles=1, numRows=510, totalSize=36345, rawDataSize=35835]
# Partition demodb.posts_sample{year=2015, month=2015-10} stats: [numFiles=1, numRows=524, totalSize=38769, rawDataSize=38245]
# Partition demodb.posts_sample{year=2015, month=2015-11} stats: [numFiles=1, numRows=501, totalSize=35668, rawDataSize=35167]
# Partition demodb.posts_sample{year=2015, month=2015-12} stats: [numFiles=1, numRows=512, totalSize=36167, rawDataSize=35655]
# Partition demodb.posts_sample{year=2016, month=2016-01} stats: [numFiles=1, numRows=552, totalSize=40290, rawDataSize=39738]
# Partition demodb.posts_sample{year=2016, month=2016-02} stats: [numFiles=1, numRows=558, totalSize=40190, rawDataSize=39632]
# Partition demodb.posts_sample{year=2016, month=2016-03} stats: [numFiles=1, numRows=619, totalSize=44457, rawDataSize=43838]
# Partition demodb.posts_sample{year=2016, month=2016-04} stats: [numFiles=1, numRows=583, totalSize=41779, rawDataSize=41196]
# Partition demodb.posts_sample{year=2016, month=2016-05} stats: [numFiles=1, numRows=576, totalSize=40501, rawDataSize=39925]
# Partition demodb.posts_sample{year=2016, month=2016-06} stats: [numFiles=1, numRows=560, totalSize=39998, rawDataSize=39438]
# Partition demodb.posts_sample{year=2016, month=2016-07} stats: [numFiles=1, numRows=533, totalSize=38958, rawDataSize=38425]
# Partition demodb.posts_sample{year=2016, month=2016-08} stats: [numFiles=1, numRows=539, totalSize=39081, rawDataSize=38542]
# Partition demodb.posts_sample{year=2016, month=2016-09} stats: [numFiles=1, numRows=517, totalSize=37111, rawDataSize=36594]
# Partition demodb.posts_sample{year=2016, month=2016-10} stats: [numFiles=1, numRows=517, totalSize=37828, rawDataSize=37311]
# Partition demodb.posts_sample{year=2016, month=2016-11} stats: [numFiles=1, numRows=509, totalSize=37731, rawDataSize=37222]
# Partition demodb.posts_sample{year=2016, month=2016-12} stats: [numFiles=1, numRows=177, totalSize=12625, rawDataSize=12448]
# Partition demodb.posts_sample{year=__HIVE_DEFAULT_PARTITION__, month=__HIVE_DEFAULT_PARTITION__} stats: [numFiles=1, numRows=1747, totalSize=41928, rawDataSize=40181]
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1   Cumulative CPU: 49.65 sec   HDFS Read: 60004585 HDFS Write: 2664244 SUCCESS
# Total MapReduce CPU Time Spent: 49 seconds 650 msec
# OK
# Time taken: 93.177 seconds
# Query ID = jovyan_20180228054444_014cf5cc-0ec6-4bc1-a55e-6630ae072514
# Total jobs = 2
# Launching Job 1 out of 2
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1519792833153_0012, Tracking URL = http://f860572437fc:8088/proxy/application_1519792833153_0012/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1519792833153_0012
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# 2018-02-28 05:44:20,006 Stage-1 map = 0%,  reduce = 0%
# 2018-02-28 05:44:30,841 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 6.8 sec
# 2018-02-28 05:44:39,400 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 11.08 sec
# MapReduce Total cumulative CPU time: 11 seconds 80 msec
# Ended Job = job_1519792833153_0012
# Launching Job 2 out of 2
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1519792833153_0013, Tracking URL = http://f860572437fc:8088/proxy/application_1519792833153_0013/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1519792833153_0013
# Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# 2018-02-28 05:44:57,907 Stage-2 map = 0%,  reduce = 0%
# 2018-02-28 05:45:06,502 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 2.62 sec
# 2018-02-28 05:45:16,234 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 8.38 sec
# MapReduce Total cumulative CPU time: 8 seconds 380 msec
# Ended Job = job_1519792833153_0013
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 11.08 sec   HDFS Read: 2708458 HDFS Write: 3481 SUCCESS
# Stage-Stage-2: Map: 1  Reduce: 1   Cumulative CPU: 8.38 sec   HDFS Read: 10329 HDFS Write: 16 SUCCESS
# Total MapReduce CPU Time Spent: 19 seconds 460 msec
# OK
# 2008	2008-10	71
# Time taken: 71.984 seconds, Fetched: 1 row(s)
